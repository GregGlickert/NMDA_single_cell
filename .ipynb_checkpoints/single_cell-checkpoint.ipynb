# %%
import matplotlib.pyplot as plt
import math
import numpy as np
import os
# %matplotlib inline

v = np.arange(-90,30,1)
temp = []
for i in range(len(v)):
    sfunc = 1/(1+(0.33*math.exp(-0.06*v[i]))) #function from mod file same as Guoshi's paper
    temp.append(sfunc)
    
temp2 = []
for i in range(len(v)):
    BB_sfunc = 1/(1+math.exp(0.07207477*-v[i])*(1/2.5522415))
    temp2.append(BB_sfunc)

plt.title("Mg block sfunc")
plt.plot(v,temp,label='guoshi')
plt.plot(v,temp2,label='blue brain')
plt.legend()
plt.xlabel('voltage (mv)')
plt.show()

RunningInCOLAB = 'google.colab' in str(get_ipython())
if RunningInCOLAB:
    # !pip install ipywidgets==7.7.1 &> /dev/null
    # !pip install neuron==8.0.0 &> /dev/null
    # !git clone https://github.com/GregGlickert/NMDA_single_cell.git &> /dev/null 
    # %cd NMDA_single_cell
os.system('nrnivmodl modfiles') # compile modfiles. Return 0 for success, 1 for failure.
# Out:
# /usr/bin/xcrun
# /Users/gregglickert/Documents/GitHub/NMDA_single_cell
# -n Mod files:
# -n  "modfiles/Gfluct_new_exc.mod"
# -n  "modfiles/Gfluct_new_inh.mod"
# -n  "modfiles/ProbAMPANMDA_EMS.mod"
# -n  "modfiles/ProbAMPANMDA_EMS_optimized.mod"
# -n  "modfiles/bg2pyr.mod"
# -n  "modfiles/bg_tone2pv.mod"
# -n  "modfiles/bg_tone2pyr.mod"
# -n  "modfiles/bginh.mod"
# -n  "modfiles/ca.mod"
# -n  "modfiles/cadyn.mod"
# -n  "modfiles/cal2.mod"
# -n  "modfiles/cal2CA3.mod"
# -n  "modfiles/capool.mod"
# -n  "modfiles/capoolCA3.mod"
# -n  "modfiles/cas.mod"
# -n  "modfiles/cat.mod"
# -n  "modfiles/currentclamp.mod"
# -n  "modfiles/function_TMonitor.mod"
# -n  "modfiles/gap.mod"
# -n  "modfiles/h.mod"
# -n  "modfiles/hCA3.mod"
# -n  "modfiles/halfgap.mod"
# -n  "modfiles/im.mod"
# -n  "modfiles/imCA3.mod"
# -n  "modfiles/kadist.mod"
# -n  "modfiles/kaprox.mod"
# -n  "modfiles/kca.mod"
# -n  "modfiles/kdrCA3.mod"
# -n  "modfiles/kdrca1.mod"
# -n  "modfiles/kdrca1DA.mod"
# -n  "modfiles/kdrinter.mod"
# -n  "modfiles/leak.mod"
# -n  "modfiles/leakCA3.mod"
# -n  "modfiles/leakDA.mod"
# -n  "modfiles/leakinter.mod"
# -n  "modfiles/na3.mod"
# -n  "modfiles/na3DA.mod"
# -n  "modfiles/nainter.mod"
# -n  "modfiles/nap.mod"
# -n  "modfiles/napCA3.mod"
# -n  "modfiles/nat.mod"
# -n  "modfiles/natCA3.mod"
# -n  "modfiles/pv2pv.mod"
# -n  "modfiles/pv2pyr.mod"
# -n  "modfiles/pv2som.mod"
# -n  "modfiles/pyr2pv.mod"
# -n  "modfiles/pyr2pyr.mod"
# -n  "modfiles/pyr2som.mod"
# -n  "modfiles/pyr2vip.mod"
# -n  "modfiles/sahp.mod"
# -n  "modfiles/sahpCA3.mod"
# -n  "modfiles/sahpNE.mod"
# -n  "modfiles/shock2int.mod"
# -n  "modfiles/som2pv.mod"
# -n  "modfiles/som2pyr.mod"
# -n  "modfiles/som2vip.mod"
# -n  "modfiles/tone2pv.mod"
# -n  "modfiles/tone2pyr.mod"
# -n  "modfiles/tone2vip.mod"
# -n  "modfiles/vecevent.mod"
# -n  "modfiles/vip2som.mod"
# -n  "modfiles/xtra.mod"
# -n  "modfiles/xtra_imemrec.mod"
#
#
# Creating x86_64 directory for .o files.
#
# COBJS=''
#  -> Compiling mod_func.c
#  -> NMODL ../modfiles/Gfluct_new_exc.mod
# clang -O2   -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c mod_func.c -o mod_func.o
#  -> NMODL ../modfiles/Gfluct_new_inh.mod
#  -> NMODL ../modfiles/ProbAMPANMDA_EMS.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl Gfluct_new_inh.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl ProbAMPANMDA_EMS.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl Gfluct_new_exc.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/bg2pyr.mod
#  -> NMODL ../modfiles/ProbAMPANMDA_EMS_optimized.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl bg2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl ProbAMPANMDA_EMS_optimized.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/bg_tone2pv.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl bg_tone2pv.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/bg_tone2pyr.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl bg_tone2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/bginh.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl bginh.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/ca.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl ca.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/cadyn.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl cadyn.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/cal2.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl cal2.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/cal2CA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl cal2CA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/capool.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl capool.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/capoolCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl capoolCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Translating Gfluct_new_exc.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/Gfluct_new_exc.c
# Translating Gfluct_new_inh.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/Gfluct_new_inh.c
# Translating ProbAMPANMDA_EMS.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/ProbAMPANMDA_EMS.c
# Notice: This mechanism cannot be used with CVODE
# Notice: This mechanism cannot be used with CVODE
# Thread Safe
# Thread Safe
# Notice: This mechanism cannot be used with CVODE
# Notice: A_AMPA discontinuity adjustment not available.
# Notice: B_AMPA discontinuity adjustment not available.
# Notice: A_NMDA discontinuity adjustment not available.
# Notice: B_NMDA discontinuity adjustment not available.
# Warning: dt undefined. (declared within VERBATIM?)
# Warning: next_delay_weight undefined. (declared within VERBATIM?)
# Warning: next_delay_t undefined. (declared within VERBATIM?)
# Thread Safe
# Translating bg2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/bg2pyr.c
# Translating ProbAMPANMDA_EMS_optimized.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/ProbAMPANMDA_EMS_optimized.c
# Thread Safe
# Translating bg_tone2pv.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/bg_tone2pv.c
# Warning: next_delay_weight undefined. (declared within VERBATIM?)
# Warning: next_delay_t undefined. (declared within VERBATIM?)
# Thread Safe
# Warning: dt undefined. (declared within VERBATIM?)
# Thread Safe
# Translating bg_tone2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/bg_tone2pyr.c
# Translating bginh.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/bginh.c
# Warning: dt undefined. (declared within VERBATIM?)
# Thread Safe
# Translating ca.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/ca.c
# Notice: VERBATIM blocks are not thread safe
# Notice: This mechanism cannot be used with CVODE
# Notice: Assignment to the GLOBAL variable, "tadj", is not thread safe
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating cadyn.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/cadyn.c
# Thread Safe
# Translating cal2.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/cal2.c
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tau", is not thread safe
# Translating cal2CA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/cal2CA3.c
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "tau", is not thread safe
# Translating capool.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/capool.c
# WARNING: xx (a STATE) is assigned a value in a DERIVATIVE block.
#  Multistep integrators (such as Runge) may not work correctly.
# Thread Safe
# Translating capoolCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/capoolCA3.c
# WARNING: xx (a STATE) is assigned a value in a DERIVATIVE block.
#  Multistep integrators (such as Runge) may not work correctly.
# Thread Safe
# Translating cas.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/cas.c
# Thread Safe
# Translating cat.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/cat.c
# Thread Safe
# Translating currentclamp.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/currentclamp.c
# Thread Safe
# Translating function_TMonitor.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/function_TMonitor.c
# Thread Safe
# Translating gap.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/gap.c
# Notice: Use of POINTER is not thread safe.
# Translating h.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/h.c
# Thread Safe
# Translating hCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/hCA3.c
# Thread Safe
# Translating halfgap.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/halfgap.c
# Thread Safe
# Translating im.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/im.c
# Thread Safe
# Translating imCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/imCA3.c
# Thread Safe
# Translating kadist.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kadist.c
# Notice: Assignment to the GLOBAL variable, "linf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "ninf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taun", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taul", is not thread safe
#  -> NMODL ../modfiles/cas.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl cas.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/cat.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl cat.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/currentclamp.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl currentclamp.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/function_TMonitor.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl function_TMonitor.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/gap.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl gap.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/h.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl h.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/hCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl hCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/halfgap.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl halfgap.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/im.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl im.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/imCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl imCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kadist.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kadist.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kaprox.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kaprox.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kca.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kca.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kdrCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kdrCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kdrca1.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kdrca1.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kdrca1DA.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kdrca1DA.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/kdrinter.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl kdrinter.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/leak.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl leak.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default -80 of PARAMETER ek will be ignored and set by NEURON.
#  -> NMODL ../modfiles/leakCA3.mod
#  -> NMODL ../modfiles/leakDA.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl leakCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl leakDA.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/leakinter.mod
# Translating kaprox.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kaprox.c
# Thread Safe
# Translating kca.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kca.c
# Translating kdrCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kdrCA3.c
# Thread Safe
# Thread Safe
# Translating kdrca1.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kdrca1.c
# Thread Safe
# Translating kdrca1DA.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kdrca1DA.c
# Translating kdrinter.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/kdrinter.c
# Thread Safe
# Thread Safe
# Translating leak.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/leak.c
# Thread Safe
# Translating leakCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/leakCA3.c
# Translating leakDA.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/leakDA.c
# Thread Safe
# Thread Safe
# Translating leakinter.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/leakinter.c
# Thread Safe
# Translating na3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/na3.c
# Translating na3DA.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/na3DA.c
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "sinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taus", is not thread safe
# Notice: Assignment to the GLOBAL variable, "htau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "hinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "mtau", is not thread safe
# Notice: Assignment to the GLOBAL variable, "minf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "sinf", is not thread safe
# Notice: Assignment to the GLOBAL variable, "taus", is not thread safe
# Translating nainter.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/nainter.c
# Thread Safe
# Translating nap.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/nap.c
# Thread Safe
# Translating napCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/napCA3.c
# Thread Safe
# Translating nat.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/nat.c
# Thread Safe
# Translating natCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/natCA3.c
# Thread Safe
# Translating pv2pv.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pv2pv.c
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating pv2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pv2pyr.c
# Translating pv2som.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pv2som.c
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl leakinter.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/na3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl na3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/na3DA.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl na3DA.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/nainter.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl nainter.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/nap.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl nap.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/napCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl napCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 45 of PARAMETER ena will be ignored and set by NEURON.
#  -> NMODL ../modfiles/nat.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl nat.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/natCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl natCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pv2pv.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pv2pv.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pv2pyr.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pv2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pv2som.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pv2som.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pyr2pv.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pyr2pv.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pyr2pyr.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pyr2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/pyr2som.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pyr2som.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/pyr2vip.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl pyr2vip.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/sahp.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl sahp.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/sahpCA3.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl sahpCA3.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/sahpNE.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl sahpNE.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating pyr2pv.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pyr2pv.c
# Notice: scop_random is not thread safe
# Translating pyr2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pyr2pyr.c
# Translating pyr2som.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pyr2som.c
# Notice: scop_random is not thread safe
# Notice: scop_random is not thread safe
# Translating pyr2vip.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/pyr2vip.c
# Notice: scop_random is not thread safe
# Translating sahp.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/sahp.c
# Translating sahpCA3.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/sahpCA3.c
# Thread Safe
# Thread Safe
# Translating sahpNE.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/sahpNE.c
# Thread Safe
# Translating som2pv.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/som2pv.c
# Translating shock2int.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/shock2int.c
# Translating som2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/som2pyr.c
# Notice: scop_random is not thread safe
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating som2vip.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/som2vip.c
# Translating tone2pv.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/tone2pv.c
# Warning: dt undefined. (declared within VERBATIM?)
# Translating tone2pyr.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/tone2pyr.c
# Thread Safe
# Warning: dt undefined. (declared within VERBATIM?)
# Thread Safe
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating tone2vip.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/tone2vip.c
# Warning: dt undefined. (declared within VERBATIM?)
# Translating vecevent.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/vecevent.c
# Notice: VERBATIM blocks are not thread safe
# Thread Safe
# Translating vip2som.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/vip2som.c
# Translating xtra.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/xtra.c
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "LFP", is not thread safe
# Notice: scop_random is not thread safe
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# WARNING: Dimensions may be wrong for READ ica with POINT_PROCESS
# Translating xtra_imemrec.mod into /Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64/xtra_imemrec.c
# Notice: Use of POINTER is not thread safe.
# Notice: Assignment to the GLOBAL variable, "LFP", is not thread safe
#  -> NMODL ../modfiles/shock2int.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl shock2int.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/som2pv.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl som2pv.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/som2pyr.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl som2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/som2vip.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl som2vip.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/tone2pv.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl tone2pv.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/tone2pyr.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl tone2pyr.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/tone2vip.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl tone2vip.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/vecevent.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl vecevent.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/vip2som.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl vip2som.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> NMODL ../modfiles/xtra.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl xtra.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
# Warning: Default 120 of PARAMETER eca will be ignored and set by NEURON.
#  -> NMODL ../modfiles/xtra_imemrec.mod
# (cd "../modfiles"; MODLUNIT=/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/share/nrn/lib/nrnunits.lib /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/bin/nocmodl xtra_imemrec.mod -o "/Users/gregglickert/Documents/GitHub/NMDA_single_cell/x86_64")
#  -> Compiling Gfluct_new_exc.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c Gfluct_new_exc.c -o Gfluct_new_exc.o
#  -> Compiling Gfluct_new_inh.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c Gfluct_new_inh.c -o Gfluct_new_inh.o
#  -> Compiling ProbAMPANMDA_EMS.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c ProbAMPANMDA_EMS.c -o ProbAMPANMDA_EMS.o
#  -> Compiling ProbAMPANMDA_EMS_optimized.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c ProbAMPANMDA_EMS_optimized.c -o ProbAMPANMDA_EMS_optimized.o
# ProbAMPANMDA_EMS.c:ProbAMPANMDA_EMS_optimized.c733::775:33: warning: passing 'unsigned char *' to parameter of type 'char *' converts between pointers to integer types with different sign [-Wpointer-sign]
# 33: warning: passing 'unsigned char *' to parameter of type 'char *' converts between pointers to integer types with different sign [-Wpointer-sign]
#     nrnran123_getseq(*pv, di+3, &which);
#                                 ^~~~~~
#     nrnran123_getseq(*pv, di+3, &which);
#                                 ^~~~~~
# /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include/nrnran123.h:47:69/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include/nrnran123.h:: note: passing argument to parameter 'which' here47:69: note: passing argument to parameter 'which' here
#
# extern void nrnran123_getseq(nrnran123_State*, uint32_t* seq, char* which);extern void nrnran123_getseq(nrnran123_State*, uint32_t* seq, char* which);
#
#                                                                     ^                                                                    ^
#
# 1 warning generated.
# 1 warning generated.
#  -> Compiling bg_tone2pv.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c bg_tone2pv.c -o bg_tone2pv.o
#  -> Compiling bg2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c bg2pyr.c -o bg2pyr.o
#  -> Compiling bg_tone2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c bg_tone2pyr.c -o bg_tone2pyr.o
#  -> Compiling bginh.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c bginh.c -o bginh.o
#  -> Compiling ca.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c ca.c -o ca.o
#  -> Compiling cadyn.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c cadyn.c -o cadyn.o
#  -> Compiling cal2.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c cal2.c -o cal2.o
#  -> Compiling cal2CA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c cal2CA3.c -o cal2CA3.o
#  -> Compiling capool.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c capool.c -o capool.o
#  -> Compiling capoolCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c capoolCA3.c -o capoolCA3.o
#  -> Compiling cas.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c cas.c -o cas.o
#  -> Compiling cat.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c cat.c -o cat.o
#  -> Compiling currentclamp.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c currentclamp.c -o currentclamp.o
#  -> Compiling function_TMonitor.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c function_TMonitor.c -o function_TMonitor.o
#  -> Compiling gap.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c gap.c -o gap.o
#  -> Compiling h.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c h.c -o h.o
#  -> Compiling halfgap.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c halfgap.c -o halfgap.o
#  -> Compiling hCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c hCA3.c -o hCA3.o
#  -> Compiling im.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c im.c -o im.o
#  -> Compiling imCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c imCA3.c -o imCA3.o
#  -> Compiling kadist.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kadist.c -o kadist.o
#  -> Compiling kaprox.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kaprox.c -o kaprox.o
#  -> Compiling kca.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kca.c -o kca.o
#  -> Compiling kdrCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kdrCA3.c -o kdrCA3.o
#  -> Compiling kdrca1.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kdrca1.c -o kdrca1.o
#  -> Compiling kdrca1DA.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kdrca1DA.c -o kdrca1DA.o
#  -> Compiling kdrinter.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c kdrinter.c -o kdrinter.o
#  -> Compiling leak.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c leak.c -o leak.o
#  -> Compiling leakCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c leakCA3.c -o leakCA3.o
#  -> Compiling leakDA.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c leakDA.c -o leakDA.o
#  -> Compiling leakinter.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c leakinter.c -o leakinter.o
#  -> Compiling na3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c na3.c -o na3.o
#  -> Compiling na3DA.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c na3DA.c -o na3DA.o
#  -> Compiling nainter.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c nainter.c -o nainter.o
#  -> Compiling nap.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c nap.c -o nap.o
#  -> Compiling napCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c napCA3.c -o napCA3.o
#  -> Compiling nat.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c nat.c -o nat.o
#  -> Compiling natCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c natCA3.c -o natCA3.o
#  -> Compiling pv2pv.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pv2pv.c -o pv2pv.o
#  -> Compiling pv2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pv2pyr.c -o pv2pyr.o
#  -> Compiling pv2som.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pv2som.c -o pv2som.o
#  -> Compiling pyr2pv.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pyr2pv.c -o pyr2pv.o
#  -> Compiling pyr2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pyr2pyr.c -o pyr2pyr.o
#  -> Compiling pyr2som.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pyr2som.c -o pyr2som.o
#  -> Compiling pyr2vip.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c pyr2vip.c -o pyr2vip.o
#  -> Compiling sahp.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c sahp.c -o sahp.o
#  -> Compiling sahpCA3.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c sahpCA3.c -o sahpCA3.o
#  -> Compiling sahpNE.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c sahpNE.c -o sahpNE.o
#  -> Compiling shock2int.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c shock2int.c -o shock2int.o
#  -> Compiling som2pv.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c som2pv.c -o som2pv.o
#  -> Compiling som2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c som2pyr.c -o som2pyr.o
#  -> Compiling som2vip.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c som2vip.c -o som2vip.o
#  -> Compiling tone2pv.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c tone2pv.c -o tone2pv.o
#  -> Compiling tone2pyr.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c tone2pyr.c -o tone2pyr.o
#  -> Compiling tone2vip.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c tone2vip.c -o tone2vip.o
#  -> Compiling vecevent.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c vecevent.c -o vecevent.o
#  -> Compiling vip2som.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c vip2som.c -o vip2som.o
#  -> Compiling xtra.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c xtra.c -o xtra.o
#  -> Compiling xtra_imemrec.c
# clang -O2   -I"../modfiles" -I.   -I/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include  -I/usr/local/Cellar/open-mpi/4.1.0/include -fPIC -c xtra_imemrec.c -o xtra_imemrec.o
#  => LINKING shared library ./libnrnmech.dylib
# clang++ -O2 -DVERSION_INFO='8.0.0' -std=c++11 -dynamiclib -Wl,-headerpad_max_install_names -undefined dynamic_lookup -fPIC  -I /Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/include -o ./libnrnmech.dylib -Wl,-install_name,@rpath/libnrnmech.dylib \
# 	  ./mod_func.o ./Gfluct_new_exc.o ./Gfluct_new_inh.o ./ProbAMPANMDA_EMS.o ./ProbAMPANMDA_EMS_optimized.o ./bg2pyr.o ./bg_tone2pv.o ./bg_tone2pyr.o ./bginh.o ./ca.o ./cadyn.o ./cal2.o ./cal2CA3.o ./capool.o ./capoolCA3.o ./cas.o ./cat.o ./currentclamp.o ./function_TMonitor.o ./gap.o ./h.o ./hCA3.o ./halfgap.o ./im.o ./imCA3.o ./kadist.o ./kaprox.o ./kca.o ./kdrCA3.o ./kdrca1.o ./kdrca1DA.o ./kdrinter.o ./leak.o ./leakCA3.o ./leakDA.o ./leakinter.o ./na3.o ./na3DA.o ./nainter.o ./nap.o ./napCA3.o ./nat.o ./natCA3.o ./pv2pv.o ./pv2pyr.o ./pv2som.o ./pyr2pv.o ./pyr2pyr.o ./pyr2som.o ./pyr2vip.o ./sahp.o ./sahpCA3.o ./sahpNE.o ./shock2int.o ./som2pv.o ./som2pyr.o ./som2vip.o ./tone2pv.o ./tone2pyr.o ./tone2vip.o ./vecevent.o ./vip2som.o ./xtra.o ./xtra_imemrec.o  -L/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/lib -lnrniv -Wl,-rpath,/Users/gregglickert/opt/anaconda3/lib/python3.9/site-packages/neuron/.data/lib    -lreadline
# rm -f ./.libs/libnrnmech.so ; mkdir -p ./.libs ; cp ./libnrnmech.dylib ./.libs/libnrnmech.so
# Successfully created x86_64/special
# 0

# %%
from neuron import h
from neuron.units import ms, mV
import matplotlib.pyplot as plt
from matplotlib import gridspec
import ipywidgets as widgets
from ipywidgets import interactive_output,HBox,VBox,Label,Layout
from IPython.display import display
from IPython.display import clear_output
import os
# %matplotlib inline

def model(tstop,ourWeight,blueBrainWeight,ourStart,blueBrainStart):
    h.load_file('stdrun.hoc')
    h.load_file('PN_cells.hoc') # reads in template
    #h.nrn_load_dll('x86_64/.libs/libnrnmech.so')
    cell = h.PN_A()
    #cell = h.InterneuronCellf()
    h.dt = 0.1 # time step (resolution) of the simulation in ms
    h.tstop = tstop # how long to run the simulation in ms
    h.v_init= -65 # initial membrane potential in mV

    t = h.Vector()      # Vectors are used to record data in the simulation
    soma_v = h.Vector()
    i_nmda_1 = h.Vector()
    i_ampa_1 = h.Vector()
    i_nmda_2 = h.Vector()
    i_ampa_2 = h.Vector()

    conn1 = h.pyr2pyr(cell.dend[0](0.9)) # makes a syn connected to soma

    t.record(h._ref_t) # derefences and records data
    soma_v.record(cell.soma[0](0.5)._ref_v)
    i_nmda_1.record(conn1._ref_inmda)
    i_ampa_1.record(conn1._ref_iampa)


    #iclamp = h.IClamp(cell.dend[0](0.5)) # current injection
    #iclamp.delay = 10050 #long enought delay turns off iclamp easy
    #iclamp.dur = 200
    #iclamp.amp = 0.3

    conn1.initW = ourWeight #synaptic weight for pyr2pyr(our synapse)
    nstim_pyr2pyr= h.NetStim(0.9)

    nstim_pyr2pyr.interval=4000 #pyrpyr synapse 
    nstim_pyr2pyr.start=ourStart
    nstim_pyr2pyr.number = 100
    nstim_pyr2pyr.noise = 0 
    nc_pyr2pyr = h.NetCon(nstim_pyr2pyr,conn1,0,0,1)

    conn2 = h.ProbAMPANMDA_EMS_optimized(cell.dend[0](0.9)) #blue brain project synapse 

    t.record(h._ref_t) # derefences and records data
    soma_v.record(cell.soma[0](0.5)._ref_v)
    i_nmda_2.record(conn2._ref_i_NMDA)
    i_ampa_2.record(conn2._ref_i_AMPA)

    #conn.weight = 0.001 #synaptic weight
    nstim_AMPANMDA_EMS= h.NetStim(0.9)

    nstim_AMPANMDA_EMS.interval=4000 #blue brain project synapse 
    nstim_AMPANMDA_EMS.start=blueBrainStart
    nstim_AMPANMDA_EMS.number = 100
    nstim_AMPANMDA_EMS.noise = 0 
    nc_AMPANMDA = h.NetCon(nstim_AMPANMDA_EMS,conn2,0,0,blueBrainWeight) #change this number to change syn weight currently it 1 

    h.finitialize(-65 * mV)
    h.continuerun(h.tstop * ms)
    
    plot(t,soma_v,i_ampa_1,i_ampa_2,i_nmda_1,i_nmda_2)

def plot(t,soma_v,i_ampa_1,i_ampa_2,i_nmda_1,i_nmda_2):
    fig = plt.figure(figsize=(15, 12),tight_layout=True) 
    gs = gridspec.GridSpec(5, 1, width_ratios=[1],height_ratios=[1,1,1,1,1]) 


    ax0 = plt.subplot(gs[0,0])
    ax1 = plt.subplot(gs[1,0])
    ax2 = plt.subplot(gs[2,0])
    ax3 = plt.subplot(gs[3,0])
    ax4 = plt.subplot(gs[4,0])
    ax0.plot(t ,soma_v)
    ax0.set_title('soma voltage')

    ax1.plot(t ,i_nmda_1)
    ax1.set_title('feng model inmda')

    ax2.plot(t,i_ampa_1)
    ax2.set_title('feng model iampa')

    ax3.plot(t,i_ampa_2)
    ax3.set_title('blue brain iampa')

    ax4.plot(t,i_nmda_2)
    ax4.set_title('blue brain inmda')
    plt.show()


tstop = 1000
ourWeight = 10
blueBrainWeight = 20
ourStart = 100
blueBrainStart = 500

w_run = widgets.Button(description='Run',icon='history',button_style='primary')
w_tstop = widgets.FloatSlider(value=tstop,min=100,max=2000, step=100,description='Tstop (ms)')
w_ourWeight = widgets.FloatSlider(value=ourWeight,min=0,max=30, step=0.5,description='feng Weight')
w_blueBrainWeight = widgets.FloatSlider(value=blueBrainWeight,min=0,max=30, step=0.5,description='BB Weight')
w_ourStart = widgets.FloatSlider(value=ourStart,min=100,max=2000, step=100,description='feng Start')
w_blueBrainStart = widgets.FloatSlider(value=blueBrainStart,min=100,max=2000, step=10,description='BB Start')
print("BB stands for blue brain projects model")
def run_model(*arges):
    clear_output()
    tstop = w_tstop.value
    ourWeight = w_ourWeight.value
    blueBrainWeight = w_blueBrainWeight.value
    ourStart = w_ourStart.value
    blueBrainStart = w_blueBrainStart.value
    print("BB stands for blue brain projects model")
    display(ui)
    model(tstop,ourWeight,blueBrainWeight,ourStart,blueBrainStart)
    
w_run.on_click(run_model)

ui = VBox([ w_run, w_tstop,HBox([w_ourWeight,w_blueBrainWeight]),HBox([w_ourStart,w_blueBrainStart])])
ui
# Out:
# BB stands for blue brain projects model
# VBox(children=(Button(button_style='primary', description='Run', icon='history', style=ButtonStyle()), FloatSl…
